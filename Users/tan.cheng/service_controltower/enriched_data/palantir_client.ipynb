# %%
from foundry_sdk.v2 import FoundryClient
import foundry_sdk
from pprint import pprint
import pandas as pd
import io
 
client = FoundryClient(auth=foundry_sdk.UserTokenAuth('eyJwbG50ciI6IjhjNkFDZjdoTkYrbHE4RC9RYWVpL1E9PSIsImFsZyI6IkVTMjU2In0.eyJqdGkiOiJjTXlMdHd4R1M2NkRhcU00YW00My9nPT0iLCJzdWIiOiJRZXk0eEZ4SVFxZS9GcnNkSGw3Yi93PT0iLCJleHAiOjE3OTczNDU0NDYsIm9yZyI6ImY4cDE5UE5FUUg2QkVQUFQvNFM5UWc9PSJ9.2AHBrzbja8GAtPw3DAigxLoYItYnow15KwSo27-DZ9Vb-rdUB9MPOb1BzhnkkLHhng-uyjZ8c4etN8TEeYRG7Q'), hostname="komatsu.palantirfoundry.com")

# %%
import pandas as pd
import io
 
def load_dataset(rid):
    content = client.datasets.Dataset.read_table(dataset_rid=rid, format="CSV")
    return pd.read_csv(io.BytesIO(content))
 
# Load all datasets
operator_events = load_dataset("ri.foundry.main.dataset.d9622959-b5e9-472d-830a-fba11453538f")          # T_OPERATOR_EVENT_HISTORY_KNA_D71
print("Operator events dataset loaded!")
cdb_prod_dmm = load_dataset("ri.foundry.main.dataset.ff363222-452f-4078-bef0-ee4fee8c310e")              # CDB_PROD_DMM
print("CDB PROD DMM dataset loaded!")
failure_codes = load_dataset("ri.foundry.main.dataset.476f338e-6f4c-416a-b21b-ac043221d68b")             # FailureCodes_FailureCodes_Master
print("Failure codes dataset loaded!")
# abnormality_history = load_dataset("ri.foundry.main.dataset.d18a17f5-0f30-4165-93fe-c1251ed1b3ad")       # T_ABNORMALITY_HISTORY_KNA_D71
# print("Abnormality history dataset loaded!")
# daily_ops = load_dataset("ri.foundry.main.dataset.81f7191b-7fef-4f7a-997c-4f4e37ff82cc")                 # T_DAILY_OPERATION_HISTORY_KNA_USE
# print("Daily operations dataset loaded!")
maintenance_history = load_dataset("ri.foundry.main.dataset.1fc53bc3-aaa9-4b16-b7e7-0b1c6051504e")       # D51_D61_D71_MAINTENANCE_HISTORY
print("Maintenance history dataset loaded!")
sap_warranty = load_dataset("ri.foundry.main.dataset.fd44fff4-7d99-45fd-a6fd-a5f3ff3c9d86")              # D51_D61_D71_WARRANTY
print("SAP warranty dataset loaded!")
service_history = load_dataset("ri.foundry.main.dataset.b3fc5341-2ec9-4ed5-904c-64f977cf307b")           # SNOW.SERVICE_HISTORY
print("Service history dataset loaded!")
fluid_samples = load_dataset("ri.foundry.main.dataset.82bce502-d79e-48b3-8c77-8da917715e51")             # SCT.V_DMM_KOWA_RESULTS_SHARE
print("Fluid samples dataset loaded!")
telemetry = load_dataset("ri.foundry.main.dataset.1fc53bc3-aaa9-4b16-b7e7-0b1c6051504e")                   # Telemetry dataset
print("Telemetry dataset loaded!")
# Out:
# Operator events dataset loaded!
# C:\Users\tcheng\AppData\Local\Temp\ipykernel_37160\1694372078.py:6: DtypeWarning: Columns (52,53,84,85,86,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(io.BytesIO(content))
# CDB PROD DMM dataset loaded!
# Failure codes dataset loaded!
# Maintenance history dataset loaded!
# ---------------------------------------------------------------------------
# ReadTableDatasetPermissionDenied          Traceback (most recent call last)
# Cell In[2], line 21
#      19 maintenance_history = load_dataset("ri.foundry.main.dataset.1fc53bc3-aaa9-4b16-b7e7-0b1c6051504e")       # D51_D61_D71_MAINTENANCE_HISTORY
#      20 print("Maintenance history dataset loaded!")
# ---> 21 sap_warranty = load_dataset("ri.foundry.main.dataset.fd44fff4-7d99-45fd-a6fd-a5f3ff3c9d86")              # D51_D61_D71_WARRANTY
#      22 print("SAP warranty dataset loaded!")
# ...

# %%
# Save all datasets to CSVs:
 
operator_events.to_csv("/home/azureuser/cloudfiles/code/warranty/data/operator_events")
cdb_prod_dmm.to_csv("/home/azureuser/cloudfiles/code/warranty/data/cdb_prod_dmm")
failure_codes.to_csv("/home/azureuser/cloudfiles/code/warranty/data/failure_codes")
maintenance_history.to_csv("/home/azureuser/cloudfiles/code/warranty/data/maintenance_history")
sap_warranty.to_csv("/home/azureuser/cloudfiles/code/warranty/data/sap_warranty")
service_history.to_csv("/home/azureuser/cloudfiles/code/warranty/data/service_history")
fluid_samples.to_csv("/home/azureuser/cloudfiles/code/warranty/data/fluid_samples")
telemetry.to_csv("/home/azureuser/cloudfiles/code/warranty/data/telemetry")
